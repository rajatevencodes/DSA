# %%
class Node(object):
    def __init__(self, val=0, left=None, right=None):
        self.data = val
        self.left = left
        self.right = right
    
class Solution:
    def insertInBST(self,root,val):
        if root is None:
            root = Node(val)
            return root
        if root.data > val:
            root.left = self.insertInBST(root.left,val)
        else:
            root.right = self.insertInBST(root.right,val)
        return root
    
    def inOrder(self,root):
        if root is None:
            return
        self.inOrder(root.left)
        print(root.data,end = " ")
        self.inOrder(root.right)
    

if __name__ == "__main__":
    root = None
    arr = [10,5,1,7,40,50]
    for i in arr:
        root = Solution().insertInBST(root,i)
    
    Solution().inOrder(root)
# Out:
# 1 5 7 10 40 50

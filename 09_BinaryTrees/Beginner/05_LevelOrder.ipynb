# %%
"""LevelOrder"""
from queue import Queue
class Node:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None


class Solution:
    def levelOrder(self, root):
        ans = []
        q = Queue()
        q.put(root)

        while not q.empty():
            level = []
            size = q.qsize()

            for _ in range(size):
                node = q.get()
                level.append(node.val)

                if node.left:
                    q.put(node.left)
                if node.right:
                    q.put(node.right)

            ans.append(level)
        return ans


if __name__ == "__main__":
    root = Node(1)
    root.left = Node(2)
    root.right = Node(3)
    root.left.left = Node(4)
    root.left.right = Node(5)
    root.right.left = Node(6)
    root.right.right = Node(7)

    solution = Solution()
    print("Level-Order Traversal:")
    print(solution.levelOrder(root))
# Out:
# Level-Order Traversal:
# [[1], [2, 3], [4, 5, 6, 7]]

# %% [markdown]
# <table>
#     <tr>
#         <td><img src="https://static.takeuforward.org/premium/Binary%20Trees/Theory%20and%20Traversals/Level%20Order%20Traversal/Level%20Order%20Traversal%20-%201.png-fEkiMPBv" alt="Dummy Image 1"></td>
#         <td><img src="https://static.takeuforward.org/premium/Binary%20Trees/Theory%20and%20Traversals/Level%20Order%20Traversal/Level%20Order%20Traversal%20-%202.png-6D-OuunH" alt="Dummy Image 2"></td>
#     </tr>
#     <tr>
#         <td><img src="https://static.takeuforward.org/premium/Binary%20Trees/Theory%20and%20Traversals/Level%20Order%20Traversal/Level%20Order%20Traversal%20-%203.png-NF5c3g0k" alt="Dummy Image 3"></td>
#         <td><img src="https://static.takeuforward.org/premium/Binary%20Trees/Theory%20and%20Traversals/Level%20Order%20Traversal/Level%20Order%20Traversal%20-%204.png-NRSOQIZj" alt="Dummy Image 4"></td>
#     </tr>
#      <td><img src="https://static.takeuforward.org/premium/Binary%20Trees/Theory%20and%20Traversals/Level%20Order%20Traversal/Level%20Order%20Traversal%20-%205.png-aeZD7w-s" alt="Dummy Image 5"></td>
#
# </table>

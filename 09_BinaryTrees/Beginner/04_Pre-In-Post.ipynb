# %%
"""PreOrder-InOrder-PostOrder"""

class Node:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None


class Solution:
    def tree_traversal(self, root):
        pre, in_order, post = [], [], []
        stack = [(root, 1)]

        while stack:
            node, state = stack.pop()
            if state == 1:
                pre.append(node.val)
                stack.append((node, 2))
                if node.left:
                    stack.append((node.left, 1))
            elif state == 2:
                in_order.append(node.val)
                stack.append((node, 3))
                if node.right:
                    stack.append((node.right, 1))
            elif state == 3:
                post.append(node.val)

        return [pre, in_order, post]


if __name__ == "__main__":
    root = Node(1)
    root.left = Node(2)
    root.right = Node(3)
    root.left.left = Node(4)
    root.left.right = Node(5)
    root.right.left = Node(6)
    root.right.right = Node(7)

    sol = Solution()
    pre, in_order, post = sol.tree_traversal(root)
    print(pre)
    print(in_order)
    print(post)
# Out:
# [1, 2, 4, 5, 3, 6, 7]
# [4, 2, 5, 1, 6, 3, 7]
# [4, 5, 2, 6, 7, 3, 1]

# %% [markdown]
# <table>
#     <tr>
#         <td><img src="https://static.takeuforward.org/premium/Binary%20Trees/Theory%20and%20Traversals/Pre,%20Post,%20Inorder%20in%20one%20traversal/All%20traversal%20at%20once%20-%201.png-txj7B7s0" alt="Dummy Image 1"></td>
#         <td><img src="https://static.takeuforward.org/premium/Binary%20Trees/Theory%20and%20Traversals/Pre,%20Post,%20Inorder%20in%20one%20traversal/All%20traversal%20at%20once%20-%202.png-wBgvKik-" alt="Dummy Image 2"></td>
#     </tr>
#     <tr>
#         <td><img src="https://static.takeuforward.org/premium/Binary%20Trees/Theory%20and%20Traversals/Pre,%20Post,%20Inorder%20in%20one%20traversal/All%20traversal%20at%20once%20-%203.png-b_mI8qLP" alt="Dummy Image 3"></td>
#         <td><img src="https://static.takeuforward.org/premium/Binary%20Trees/Theory%20and%20Traversals/Pre,%20Post,%20Inorder%20in%20one%20traversal/All%20traversal%20at%20once%20-%204.png-WEIN1kba" alt="Dummy Image 4"></td>
#     </tr>
#     <tr>
#         <td><img src="https://static.takeuforward.org/premium/Binary%20Trees/Theory%20and%20Traversals/Pre,%20Post,%20Inorder%20in%20one%20traversal/All%20traversal%20at%20once%20-%205.png-LOwD2K-T" alt="Dummy Image 5"></td>
#         <td><img src="https://static.takeuforward.org/premium/Binary%20Trees/Theory%20and%20Traversals/Pre,%20Post,%20Inorder%20in%20one%20traversal/All%20traversal%20at%20once%20-%206.png-1ahYjhJz" alt="Dummy Image 6"></td>
#     </tr>
#      <tr>
#         <td><img src="https://static.takeuforward.org/premium/Binary%20Trees/Theory%20and%20Traversals/Pre,%20Post,%20Inorder%20in%20one%20traversal/All%20traversal%20at%20once%20-%207.png-7i9d64dh" alt="Dummy Image 7"></td>
#         <td><img src="https://static.takeuforward.org/premium/Binary%20Trees/Theory%20and%20Traversals/Pre,%20Post,%20Inorder%20in%20one%20traversal/All%20traversal%20at%20once%20-%208.png-yftJ91hX" alt="Dummy Image 8"></td>
#     </tr>
# </table>
